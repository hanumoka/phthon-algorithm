# %% [markdown]
# # 피아노 건반에서 최단거리 찾기

# %% [markdown]
#  ![피아노건반](img/피아노건반2.png)

# %% [markdown]
# # 위처럼 짧은 피아노 건반이 있다.
# - 흰건반 : 1,3,5,7,8,10,12
# - 검은건반: 2,4,6,9,11
#
# 조건
# - 시작 말은 무조건 1 부터 시작한다.
# - 말의 이동은 인접한 건반을 거쳐 이동할 수 있다.
# - 말의 위치가 1인경우 2,3 으로 이동 가능
# - 말의 위치가 3인 경우 1,2,4,5 이동 가능
# - 말의 위치가 8인 경우 7, 9, 10 이동 가능
#
# 문제
# [5, 7, 12, 2] 와 같이 건반 숫자 배열이 있는 경우 1부터 시작하는 말의 최단 이동거리를 리턴하라.
#
# 입력예시1 => [5, 7, 12, 2]
#
# 출력예시1 => 12
#
# 입력예시2 => [3, 4, 11, 5]
#
# 출력예시2 => 11

# %% [markdown]
# ### 검사대상

# %%
test_1 = { 'name': 'test_1', 'q': [5,7,12,2], 'a': 12}
test_2 = { 'name': 'test_2', 'q':  [3,4,11,5], 'a': 11}

test_list = [test_1, test_2]

# %% [markdown]
# ### 솔루션

# %%
def solution(q_array):
#     print(q_array)
    answer = 0
    
    return answer

# %% [markdown]
# ### 검사코드

# %%
for test in test_list:
    res = solution(test)
    if res != test['a']:
        print(test['name'] + "실패")
    else:
        print(test['name'] + "성공")
# Out:
# test_1실패
# test_2실패
